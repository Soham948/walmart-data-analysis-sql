# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Walmart\\walmart_clean_data.csv")

# %%
df
# Out:
#       invoice_id   Branch         City                category unit_price  \
# 0              1  WALM003  San Antonio       Health and beauty     $74.69
# 1              2  WALM048    Harlingen  Electronic accessories     $15.28
# 2              3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3              4  WALM064      Bedford       Health and beauty     $58.22
# 4              5  WALM013       Irving       Sports and travel     $86.31
# ...          ...      ...          ...                     ...        ...
# 9964        9996  WALM056      Rowlett     Fashion accessories        $37
# 9965        9997  WALM030   Richardson      Home and lifestyle        $58
# 9966        9998  WALM050     Victoria     Fashion accessories        $52
# 9967        9999  WALM032        Tyler      Home and lifestyle        $79
# 9968       10000  WALM069     Rockwall     Fashion accessories        $62
#
#       quantity      date      time payment_method  rating  profit_margin
# ...

# %% [markdown]
# ### Step 1
# ### Data explorating

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df.shape
# Out:
# (9969, 11)

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty     $74.69
# 1           2  WALM048    Harlingen  Electronic accessories     $15.28
# 2           3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3           4  WALM064      Bedford       Health and beauty     $58.22
# 4           5  WALM013       Irving       Sports and travel     $86.31
#
#    quantity      date      time payment_method  rating  profit_margin
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48

# %%
df.describe()
# Out:
#          invoice_id     quantity       rating  profit_margin
# count   9969.000000  9969.000000  9969.000000    9969.000000
# mean    5010.116561     2.355602     5.828839       0.393744
# std     2886.217349     1.605455     1.763723       0.090659
# min        1.000000     1.000000     3.000000       0.180000
# 25%     2524.000000     1.000000     4.000000       0.330000
# 50%     5016.000000     2.000000     6.000000       0.330000
# 75%     7508.000000     3.000000     7.000000       0.480000
# max    10000.000000    10.000000    10.000000       0.570000

# %%
df.isnull().sum()
# Out:
# invoice_id        0
# Branch            0
# City              0
# category          0
# unit_price        0
# quantity          0
# date              0
# time              0
# payment_method    0
# rating            0
# profit_margin     0
# dtype: int64

# %%
df.dtypes
# Out:
# invoice_id          int64
# Branch             object
# City               object
# category           object
# unit_price         object
# quantity          float64
# date               object
# time               object
# payment_method     object
# rating            float64
# profit_margin     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9969 entries, 0 to 9968
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      9969 non-null   int64
#  1   Branch          9969 non-null   object
#  2   City            9969 non-null   object
#  3   category        9969 non-null   object
#  4   unit_price      9969 non-null   object
#  5   quantity        9969 non-null   float64
#  6   date            9969 non-null   object
#  7   time            9969 non-null   object
#  8   payment_method  9969 non-null   object
#  9   rating          9969 non-null   float64
#  10  profit_margin   9969 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 856.8+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# invoice_id        0
# Branch            0
# City              0
# category          0
# unit_price        0
# quantity          0
# date              0
# time              0
# payment_method    0
# rating            0
# profit_margin     0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (9969, 11)

# %%
#droping all rows with missing records
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# invoice_id        0
# Branch            0
# City              0
# category          0
# unit_price        0
# quantity          0
# date              0
# time              0
# payment_method    0
# rating            0
# profit_margin     0
# dtype: int64

# %%
df["unit_price"]=df["unit_price"].str.replace("$","").astype('float')

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity      date      time payment_method  rating  profit_margin
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48

# %%
df['unit_price'].astype
# Out:
# <bound method NDFrame.astype of 0       74.69
# 1       15.28
# 2       46.33
# 3       58.22
# 4       86.31
#         ...
# 9964    37.00
# 9965    58.00
# 9966    52.00
# 9967    79.00
# 9968    62.00
# Name: unit_price, Length: 9969, dtype: float64>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9969 entries, 0 to 9968
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      9969 non-null   int64
#  1   Branch          9969 non-null   object
#  2   City            9969 non-null   object
#  3   category        9969 non-null   object
#  4   unit_price      9969 non-null   float64
#  5   quantity        9969 non-null   float64
#  6   date            9969 non-null   object
#  7   time            9969 non-null   object
#  8   payment_method  9969 non-null   object
#  9   rating          9969 non-null   float64
#  10  profit_margin   9969 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 856.8+ KB

# %%
df.columns
# Out:
# Index(['invoice_id', 'Branch', 'City', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin'],
#       dtype='object')

# %%
df.columns=df.columns.str.lower()

# %%
df['total']=df['unit_price']*df['quantity']

# %%
df.head()
# Out:
#    invoice_id   branch         city                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity      date      time payment_method  rating  profit_margin   total
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48  522.83
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48   76.40
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33  324.31
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33  465.76
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48  604.17

# %%
df.columns
# Out:
# Index(['invoice_id', 'branch', 'city', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin', 'total'],
#       dtype='object')

# %%
#physcopg2#this will work as a adaptor connecror

# %% [markdown]
# ## connecting with sql

# %%
import psycopg2
from sqlalchemy import create_engine

# %%
host='localhost'
port='5432'
user='postgres'
password='root'
database='walmart_db'


engine=create_engine(f"postgresql+psycopg2://postgres:root@localhost:5432/walmart_db")

try:
    engine
    print("connection Succsed to PSQL")
except:
    print("unavble to connect")

#table_name="Tableloan"
# Out:
# connection Succsed to PSQL

# %%
table_name = "Walmart"

df.to_sql(table_name, engine, if_exists="replace", index=False)

print("Data successfully loaded!")
# Out:
# Data successfully loaded!

# %%
#we are going to export this dtaa  in sql postgres

# %%
df.to_csv('Walmart_clean_data.csv',index=False)
